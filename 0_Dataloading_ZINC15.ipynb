# %%
import pandas as pd
import numpy as np

# %%
#subset = pd.read_csv('../datasets/ZINC15_testset.txt', sep='t', header=)

subset = pd.read_table('../datasets/ZINC15_testset.txt', sep='t')

# %%
subset
# Out:
#                    smiles  zinc_id inchikey        mw      logp    reac  \
# 0   C[C@H](C(=O)O)c1ccc2oc(-c3ccc(Cl)cc3)nc2c1    ...               iga
# 1   COc1ccc2c(c1)N(CCCN(C)C)c1ccccc1S2      ZINC00...               NaN
# 2   CC(C)(Oc1ccc([C@@H]2CCCc3ccccc32)cc1)C(=O)O   ...               NaN
# 3   COC(=O)C(C)(C)Oc1ccc(-c2ccc(Cl)cc2)cc1  ZINC00...               NaN
# 4   O=C(O)Cc1cscc1Nc1c(Cl)cccc1Cl   ZINC0000000013...               NaN
# 5   O[C@H]1CCCc2nc3ccccc3c(NCc3ccccc3)c21   ZINC00...               NaN
# 6   Nc1ccc(-c2nc3ccccc3s2)cc1Br     ZINC0000000214...               NaN
# 7   CC1(C)CC(NSc2nc3ccccc3s2)CC(C)(C)N1     ZINC00...               NaN
# 8   O=C(CN1CCCCC1)N1c2ccccc2C=Cc2ccccc21    ZINC00...               NaN
# 9   O=C1OC(c2ccccc2Cl)=N/C1=C/c1ccc(Cl)cc1  ZINC00...               NaN
# 10  O=C1OC(c2cccc(Cl)c2)=N/C1=C/c1ccc(Cl)cc1      ...               NaN
# 11  CC(C)(C)c1ccc(C2=N/C(=C/c3cccs3)C(=O)O2)cc1   ...               NaN
# ...
