# %%
import pandas as pd
from IPython.display import Audio
sound_file = '../diving.mp3'
import re
import numpy as np
import pubchempy as pcp
from SmilesPE.pretokenizer import atomwise_tokenizer

# %%
shared_alphabet = {'Cl', ')', '3', '8', 'O', 'P', 'F', 'S', '[O-]', 'N', '[N-]', '1', '=', 'Br', '4', '#', '6', '7', 'I', '(', '9', '5', '[N+]', 'C', '2'}
filepath_Lenselink_full_dataset = '../datasets/Lenselink_et_al/Dataset_files_342_MB/data/Supplementary_Information/dataset/compound_additional_physchem_features.txt'

# %% [markdown]
# ## Getting the ChEMBL IDs from all Lenselink compounds

# %%
list_lense_Chemblids = []

with open(filepath_Lenselink_full_dataset) as ds:

    for index, line in enumerate(ds):

        current_search = re.search('^(CHEMBL[0-9]+)\t.+$', line)
        if current_search:
            list_lense_Chemblids.append(current_search.group(1))   
        else:
            continue

# %%
# write the list to a file
#with open('../datasets/Lenselink_et_al/Lenselink_Cleaning_A_chemblids.txt', 'w') as Lense_chemblids_file:
#    for id in list_lense_Chemblids:
#        Lense_chemblids_file.write("%s\n" % id)

# %% [markdown]
# ## Mapping the PubChem IDs to the ChEMBL IDs

# %%
unichem = pd.read_table('../datasets/UniChem_Mapping/src1src22.txt')
unichem.rename(columns={"From src:'1'": "chembl_id", "To src:'22'": "pubchem_id"}, inplace=True)
unichem = unichem.astype(dtype={'pubchem_id':'object'})

# %%
# turn the list into a DataFrame
df_lense = pd.DataFrame(columns=['lense_chembl_id'])
df_lense['lense_chembl_id'] = list_lense_Chemblids

# %%
lense = pd.merge(df_lense, unichem,
                  how='left',
                  left_on='lense_chembl_id', right_on='chembl_id')
lense.drop_duplicates(subset='pubchem_id', keep='first', inplace=True, ignore_index=True)
lense.dropna(axis=0, how='any', inplace=True)
lense.reset_index(drop=True)
# Out:
#        lense_chembl_id      chembl_id pubchem_id
# 0        CHEMBL2364776  CHEMBL2364776   60162406
# 1        CHEMBL2365129  CHEMBL2365129   71561420
# 2          CHEMBL29641    CHEMBL29641       1714
# 3        CHEMBL1229592  CHEMBL1229592   44607530
# 4         CHEMBL360190   CHEMBL360190   10396070
# ...                ...            ...        ...
# 197363   CHEMBL2172055  CHEMBL2172055   71460740
# 197364   CHEMBL2146864  CHEMBL2146864   71454646
# 197365   CHEMBL3304900  CHEMBL3304900    3048938
# 197366   CHEMBL3274623  CHEMBL3274623    3048936
# 197367   CHEMBL3305786  CHEMBL3305786    3048942
#
# [197368 rows x 3 columns]

# %% [markdown]
# ## Mapping the PubChem SMILES to the PubChem IDs

# %%
lense['canonical_smiles'] = ''
for row in lense.index:
    entry = pcp.Compound.from_cid(lense.iat[row, 2])
    lense.iat[row, 3] = entry.canonical_smiles
    
Audio(sound_file, autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-25c9dad4b797> in <module>
#       1 lense['canonical_smiles'] = ''
#       2 for row in lense.index:
# ----> 3     entry = pcp.Compound.from_cid(lense.iat[row, 2])
#       4     lense.iat[row, 3] = entry.canonical_smiles
#       5
#
# ~/anaconda3/envs/wonderland/lib/python3.6/site-packages/pubchempy.py in from_cid(cls, cid, **kwargs)
#     724         :param int cid: The PubChem Compound Identifier (CID).
#     725         """
# --> 726         record = json.loads(request(cid, **kwargs).read().decode())['PC_Compounds'][0]
#     727         return cls(record)
#     728
#
# ~/anaconda3/envs/wonderland/lib/python3.6/site-packages/pubchempy.py in request(identifier, namespace, domain, operation, output, searchtype, **kwargs)
#     269         log.debug('Request URL: %s', apiurl)
#     270         log.debug('Request data: %s', postdata)
# --> 271         response = urlopen(apiurl, postdata)
#     272         return response
#     273     except HTTPError as e:
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/envs/wonderland/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316             try:
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1260                 encode_chunked=False):
#    1261         """Send a complete request to the server."""
# -> 1262         self._send_request(method, url, body, headers, encode_chunked)
#    1263
#    1264     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1306             # default charset of iso-8859-1.
#    1307             body = _encode(body, 'body')
# -> 1308         self.endheaders(body, encode_chunked=encode_chunked)
#    1309
#    1310     def getresponse(self):
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1255         else:
#    1256             raise CannotSendHeader()
# -> 1257         self._send_output(message_body, encode_chunked=encode_chunked)
#    1258
#    1259     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1034         msg = b"\r\n".join(self._buffer)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#    1038         if message_body is not None:
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in send(self, data)
#     972         if self.sock is None:
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#     976                 raise NotConnected()
#
# ~/anaconda3/envs/wonderland/lib/python3.6/http/client.py in connect(self)
#    1421
#    1422             self.sock = self._context.wrap_socket(self.sock,
# -> 1423                                                   server_hostname=server_hostname)
#    1424             if not self._context.check_hostname and self._check_hostname:
#    1425                 try:
#
# ~/anaconda3/envs/wonderland/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~/anaconda3/envs/wonderland/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# ~/anaconda3/envs/wonderland/lib/python3.6/ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# ~/anaconda3/envs/wonderland/lib/python3.6/ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:

# %%
lense.loc[25100:25150]
# Out:
#       lense_chembl_id      chembl_id pubchem_id  \
# 25100   CHEMBL2334631  CHEMBL2334631   25192356
# 25101   CHEMBL2334643  CHEMBL2334643   25192509
# 25102   CHEMBL2334646  CHEMBL2334646   25192510
# 25103   CHEMBL3127535  CHEMBL3127535   76329166
# 25104   CHEMBL3127536  CHEMBL3127536   76314705
# 25105   CHEMBL3127665  CHEMBL3127665   76336462
# 25106   CHEMBL3127654  CHEMBL3127654   76332842
# 25107   CHEMBL3093866  CHEMBL3093866   71657335
# 25108   CHEMBL3093868  CHEMBL3093868   71657232
# 25109   CHEMBL3093865  CHEMBL3093865   71657233
# 25110   CHEMBL3093871  CHEMBL3093871   71657340
# 25111   CHEMBL3093862  CHEMBL3093862   71657548
# 25112   CHEMBL3093876  CHEMBL3093876   72725460
# 25113   CHEMBL3093867  CHEMBL3093867   71657336
# 25114   CHEMBL3093874  CHEMBL3093874   71657441
# 25115   CHEMBL3093882  CHEMBL3093882   71657338
# 25116   CHEMBL3093860  CHEMBL3093860   71657445
# 25117   CHEMBL3093863  CHEMBL3093863   71657549
# 25111  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC5=C(S4...
# 25112  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC=C(S4)...
# 25113      CC1=CSC(=N1)NC(=O)N2CCC(CC2)N3CCCC4=CC=CC=C43
# 25114  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC=C(S4)CCO
# 25115  CNC(=O)C1=CC(=CC=C1)NC(=O)N2CCC(CC2)N3C=CC4=CC...
# 25116  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC5=C(S4...
# 25117  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NN5CCNC(...
# 25118  CNC(=O)C1=CN=C(S1)NC(=O)N2CCC(CC2)N3CCC4=C3C=C...
# 25119  C1CCC2=C(C1)N=C(S2)NC(=O)N3CCC(CC3)N4CCC5=C4C=...
# 25120  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC5=C(S4...
# 25121   CC1=CSC(=N1)NC(=O)N2CCC(CC2)C3=NOC4=C3C=C(C=C4)F
# 25122  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC(=CS4)...
# 25123  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC(=CS4)CCO
# 25124  C1CC2=C(CC1O)SC(=N2)NC(=O)N3CCC(CC3)N4CCC5=C4C...
# 25125    CC1=CN=C(S1)NC(=O)N2CCC(CC2)N3CCC4=C3C=C(C=C4)F
# 25126   C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C(=O)NC4=NC=C(S4)CO
# 25127  CNC(=O)C1=CC(=CC=C1)NC(=O)N2CCC(CC2)N3CCC4=CC=...
# 25128  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C4=NN=C(C=C4)C5=C...
# 25129  CN1C=C(C=N1)C2=NN=C(C=C2)N3CCC(CC3)N4C=CC5=CC=...
# 25130  C1CN(CCC1N2CCC3=C2C=C(C=C3)F)C4=NN=C(C=C4)C5=C...
# 25131  CNC(=O)C1=NC=C(C=C1)C2=NN=C(C=C2)N3CCC(CC3)N4C...
# 25132  CN1C=C(C=N1)C2=NN=C(C=C2)N3CCC(CC3)N4C5=C(C=CC...
# 25133
# 25134
# 25135
# 25136
# 25137
# 25138
# 25139
# 25140
# 25141
# 25142
# 25143
# 25144
# 25145
# 25146
# 25147
# 25148
# 25149
# 25150

# %%
# drop the chembl columns
lense.drop(columns=['lense_chembl_id', 'chembl_id'])

# drop nas
lense.dropna(how='any', inplace=True)
lense.reset_index(drop=True)

# %% [markdown]
# ## Filter the SMILES for subsets of shared alphabet

# %%
# generate the tokens
lense['tokens'] = ''
for row in lense.index:
    lense.at[row, 'tokens'] = atomwise_tokenizer(lense.at[row, 'canonical_smiles'])

# %%
for row in lense.index:
    entry = pcp.Compound.from_cid(lense.iat[row, 2])
    lense.iat[row, 3] = entry.canonical_smiles
    
Audio(sound_file, autoplay=True)


shared_alphabet
